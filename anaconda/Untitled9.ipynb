# %%
Jupyter Notebook
main.py
Last Sunday at 13:15
Python
File
Edit
View
Language
98
#         driver.get("https://www.gstatic.com/generate_204")
99
#         log("Navigated to the captive portal.")
100

101
#         WebDriverWait(driver, 10).until(EC.number_of_windows_to_be(2))
102
#         driver.switch_to.window(driver.window_handles[1])
103
#         log("Switched to the new tab.")
104

105
#         WebDriverWait(driver, 10).until(
106
#             EC.presence_of_element_located((By.NAME, "username"))
107
#         ).send_keys(username)
108
#         WebDriverWait(driver, 10).until(
109
#             EC.presence_of_element_located((By.NAME, "password"))
110
#         ).send_keys(password)
111
#         log("Entered the credentials.")
112

113
#         continue_button = WebDriverWait(driver, 10).until(
114
#             EC.element_to_be_clickable((By.XPATH, "//input[@type='submit']"))
115
#         )
116
#         continue_button.click()
117
#         log("Clicked the 'Continue' button.")
118
#     except TimeoutException:
119
#         log("Timed out waiting for page elements.")
120
#     except NoSuchElementException as e:
121
#         log(f"Element not found: {e}")
122
#     except WebDriverException as e:
123
#         log(f"WebDriver error: {e}")
124
#     finally:
125
#         driver.quit()
126
#         log("Closed the browser.")
127

128
# def check_and_login():
129
#     ssid = "IIT(BHU)"
130
#     connected, internet = is_connected_to_wifi_macos(ssid)
131
#     if connected:
132
#         if internet:
133
#             log(f"Connected to {ssid} with internet access")
134
#         else:
135
#             log(f"Connected to {ssid} but no internet access")
136
#             logout()
137
#             username, password = read_credentials()
138
#             if username and password:
139
#                 for attempt in range(2):
140
#                     login_to_portal(username, password)
141
#                     _, internet = is_connected_to_wifi_macos(ssid)
142
#                     if internet:
143
#                         log("Successfully logged into the captive portal.")
144
#                         break
145
#                     else:
146
#                         log(f"Attempt {attempt + 1} failed. Retrying...")
147
#             else:
148
#                 log("No credentials found to log in.")
149
#     else:
150
#         log(f"Not connected to {ssid}")
151

152
# def run_periodically():
153
#     while True:
154
#         check_and_login()
155
#         time.sleep(15)  # 15 seconds
156

157
# def start_periodic_checks():
158
#     periodic_thread = threading.Thread(target=run_periodically, daemon=True)
159
#     periodic_thread.start()
160

161
# def log(message):
162
#     log_text.config(state=tk.NORMAL)
163
#     log_text.insert(tk.END, message + "\n")
164
#     log_text.config(state=tk.DISABLED)
165
#     log_text.see(tk.END)
166
​
167
# root = tk.Tk()
168
# root.title("Credential Manager")
169

170
# # Ensure icon.png is in the working directory
171
# img = tk.PhotoImage(file='icon.png')
172
# root.tk.call('wm', 'iconphoto', root._w, img)
173

174
# frame = tk.Frame(root)
175
# frame.pack(pady=20)
176

177
# enter_button = tk.Button(frame, text="Enter Credentials", command=enter_credentials)
178
# enter_button.pack(pady=10)
179
